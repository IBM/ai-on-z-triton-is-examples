# %% [markdown]
# ## Download data
# https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia

# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image

from src.utils import plot_CXR_images, plot_CXR_images_big
# Out:
# 2023-08-14 14:28:31.116623: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plot_CXR_images(path = "chest_xray/train/PNEUMONIA/")

# %%
plot_CXR_images(path = "chest_xray/train/NORMAL/")

# %%
plot_CXR_images_big()
